# %% [markdown]
# # **0. COLLECTING DATA**

# %% [markdown]
# ## Import thư viện cần thiết

# %%
import pandas as pd

# %% [markdown]
# ## Đọc dữ liệu

# %%
df = pd.read_csv("../data/vn_music_all.csv")
print("Tổng quan dữ liệu:")
df.info()
# Out:
# Tổng quan dữ liệu:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7353 entries, 0 to 7352
# Data columns (total 31 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   video_id                     7353 non-null   object
#  1   published_at                 7353 non-null   object
#  2   channel_id                   7353 non-null   object
#  3   channel_title                7353 non-null   object
#  4   title                        7353 non-null   object
#  5   description                  0 non-null      float64
#  6   tags                         0 non-null      float64
#  7   category_id                  7353 non-null   int64
#  8   default_language             7353 non-null   object
#  9   default_audio_language       7353 non-null   object
#  10  is_vietnamese_language_flag  7353 non-null   bool
#  11  has_vietnamese_diacritics    7353 non-null   bool
#  12  in_publish_range             7353 non-null   bool
#  13  accepted                     7353 non-null   bool
#  14  filter_reason                7353 non-null   object
#  15  view_count                   7353 non-null   int64
#  16  like_count                   6858 non-null   float64
#  17  comment_count                7242 non-null   float64
#  18  duration                     7353 non-null   object
#  19  definition                   7353 non-null   object
#  20  caption                      7353 non-null   bool
#  21  licensed_content             7353 non-null   bool
#  22  privacy_status               7353 non-null   object
#  23  made_for_kids                7353 non-null   bool
#  24  tags_count                   7353 non-null   int64
#  25  topic_categories             7338 non-null   object
#  26  raw_json                     7353 non-null   object
#  27  source_folder                7353 non-null   object
#  28  source_csv_path              7353 non-null   object
#  29  search_query_used            7353 non-null   object
#  30  crawl_timestamp_utc          7353 non-null   object
# dtypes: bool(7), float64(4), int64(3), object(17)
# memory usage: 1.4+ MB

# %%
df.head(5)
# Out:
#       video_id          published_at                channel_id  \
# 0  zTMI-LgAeyE  2025-12-31T23:01:38Z  UC2CjF8lJcRxRZ1TCsceVP7g
# 1  Xua2LkJ0jM0  2025-12-31T23:01:00Z  UCaLvdyzSFAfrB0A2BNQZYhQ
# 2  6jEYb_2QXAI  2025-12-31T22:16:26Z  UC6dg-5Dg6fB3B7Kj6MK_umw
# 3  MqjTEJ6NYJg  2025-12-31T12:30:07Z  UCocyTID1JieKnhb9eQQT_tg
# 4  Hc0fn7Z4Yms  2025-12-31T12:02:38Z  UCgLtSn3RGfd2-Qv6vbFTeig
#
#               channel_title  \
# 0  Nhạc Test Loa Chuẩn Nhất
# 1      Relaxing Piano Music
# 2        Tình Khúc Trữ Tình
# 3           Nam Em Official
# 4                Phê Music
#
#                                                title  description  tags  \
# 0  LK Nhạc Xuân Không Lời SÔI ĐỘNG NHẤT2026 - Hòa...          NaN   NaN
# 1  Nhạc Không Lời Tăng Năng Lượng Tích Cực Cho Ng...          NaN   NaN
# 2  Nhạc BOLERO Trữ Tình Hay Nhất, Độc Lạ 2025 - N...          NaN   NaN
# 3  KHÚC GIAO MÙA - NAM EM & NAM ANH | OFFICIAL MV...          NaN   NaN
# 4  Chưa Từng Đậm Sâu Remix - Inso (Bản Hít) | Anh...          NaN   NaN
#
#    category_id default_language default_audio_language  ...  licensed_content  \
# 0           10               vi                     vi  ...              True
# 1           10               vi                     vi  ...             False
# 2           10               vi                     vi  ...              True
# 3           10               vi                     vi  ...              True
# 4           10               vi                     vi  ...              True
#
#    privacy_status  made_for_kids  tags_count  \
# 0          public          False          26
# 1          public          False          19
# 2          public          False          27
# 3          public          False           1
# 4          public          False          27
#
#                                     topic_categories  \
# 0  https://en.wikipedia.org/wiki/Music|https://en...
# 1  https://en.wikipedia.org/wiki/Classical_music|...
# 2  https://en.wikipedia.org/wiki/Music|https://en...
# 3  https://en.wikipedia.org/wiki/Music|https://en...
# 4  https://en.wikipedia.org/wiki/Electronic_music...
#
#                                             raw_json         source_folder  \
# 0  {"kind": "youtube#video", "etag": "5qAVZzfzzn7...        nhạc không lời
# 1  {"kind": "youtube#video", "etag": "fFrHMJmKan4...        nhạc không lời
# 2  {"kind": "youtube#video", "etag": "cpI-C01KYNC...                  nhạc
# 3  {"kind": "youtube#video", "etag": "sSGX7yy9nj0...           nhạc_tết_mv
# 4  {"kind": "youtube#video", "etag": "YetjokFRD18...  nhạc_trẻ_music_video
#
#                                      source_csv_path     search_query_used  \
# 0  /home/doanxem99/programming/school/DataVisuali...        nhạc không lời
# 1  /home/doanxem99/programming/school/DataVisuali...        nhạc không lời
# 2  /home/doanxem99/programming/school/DataVisuali...                  nhạc
# 3  /home/doanxem99/programming/school/DataVisuali...           nhạc tết mv
# 4  /home/doanxem99/programming/school/DataVisuali...  nhạc trẻ music video
#
#     crawl_timestamp_utc
# 0  2026-04-30T16:39:06Z
# 1  2026-04-30T16:39:06Z
# 2  2026-04-30T15:34:13Z
# 3  2026-04-30T16:26:07Z
# 4  2026-04-30T16:01:38Z
#
# [5 rows x 31 columns]

# %% [markdown]
# ## Tổng quan đặc trưng (features)
#
# Bộ dữ liệu chứa 7353 mẫu video với 31 đặc trưng:
#
# - `video_id` - Mã định danh duy nhất của video trên YouTube.
# - `published_at` - Thời điểm video được đăng lên.
# - `channel_id` - Mã định danh duy nhất của kênh đăng tải video.
# - `channel_title` - Tên kênh đăng tải video.
# - `title` - Tiêu đề đầy đủ của video.
# - `description` - Nội dung mô tả chi tiết bên dưới video.
# - `tags` - Danh sách các từ khóa/thẻ gắn kèm video.
# - `category_id` - Mã số danh mục của video.
# - `default_language` - Ngôn ngữ mặc định của video.
# - `default_audio_language` - Ngôn ngữ mặc định của âm thanh video.
# - `is_vietnamese_language_flag` - Cờ để kiểm tra video dùng tiếng Việt (có/không).
# - `has_vietnamese_diacritics` - Mã vùng của video (vi/null).
# - `in_publish_range` - Thời điểm tải lên nằm trong khoảng nhóm khảo sát (có/không).
# - `accepted` - Thỏa mãn điều kiện (có/không) - mấy biến này mai t bỏ hếc.
# - `filter_reason` - Hết bíc
# - `view_count` - Tổng số lượt xem của video.
# - `like_count` - Tổng số lượt thích của video.
# - `comment_count` - Tổng số lượt bình luận của video.
# - `duration` - Thời lượng video (theo chuẩn ISO 8601).
# - `definition` - Chịu hua (chất lượng video hả).
# - `caption` - Trạng thái video có phụ đề hay không (có/không).
# - `licensed_content` - Tình trạng bản quyền của video (đúng ko z) (có/không).
# - `privacy_status` - Chế độ riêng tư của video (private/unlisted/public).
# - `made_for_kids` - Nội dung cho trẻ em (có/không).
# - `tags_count` - Chi má.
# - `topic_categories` - Các chủ đề liên quan (dạng link Wikipedia).
# - `raw_json` - ?
# - `source_folder` - bỏ nga.
# - `source_csv_path` - như trên
# - `search_query_used` - Truy vấn dùng để tìm video.
# - `crawl_timestamp_utc` - Thời gian thu thập dữ liệu (theo chuẩn UTC).
